# %%
print("Hello World!")

# %%
# %sql
select "Hello World from SQL!"

# %% [markdown]
# # MArkDown
#
# 1. Hello
# 2. World
#
# * Hi
# * python
#
# | Name | id|
# | ---------- | --------|
# | Ajay | 2408944 |

# %%
# %run ./includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
files = dbutils.fs.ls("/databricks-datasets")
print(files)

# %%
display(files)
